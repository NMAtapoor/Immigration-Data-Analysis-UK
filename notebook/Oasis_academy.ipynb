# %%
# STEP 1: Import libraries

import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# STEP 2: Load the Excel dataset
DATA_PATH = Path("../data/rawData/Oasis_data.xlsx")

df = pd.read_excel(DATA_PATH)

df.head()
